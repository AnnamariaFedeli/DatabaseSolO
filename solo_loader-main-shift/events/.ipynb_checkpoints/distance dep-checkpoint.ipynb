# %%
from matplotlib.ticker import LinearLocator, MultipleLocator, AutoMinorLocator
import matplotlib.dates as mdates
from matplotlib.ticker import FormatStrFormatter
from adjustText import adjust_text
from astropy import units as u
import sys
import site
import matplotlib.pyplot as plt
from math import *
from tkinter import *
import astropy.units as u
import numpy as np
import pandas as pd
import plotly.express as px

# %%
fit_run = pd.read_excel(r'C:\Users\Omistaja\Desktop\SRL\2021SRL\epd_plot-main\solo_loader-main-shift\events\fit-run-all.xlsx')
make_fit = pd.read_excel(r'C:\Users\Omistaja\Desktop\SRL\2021SRL\epd_plot-main\solo_loader-main-shift\events\make-fit.xlsx')

# %%
data_all = pd.concat([fit_run, make_fit], axis=1)
data = data_all.where((data_all.final_fit_type == "broken") & (data_all.distance_au<=0.7) , np.nan)
data_c = data_all.where((data_all.final_fit_type == "broken")& (data_all.distance_au>0.7), np.nan)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=283, step=1)

# %%
step_ept_het = data.where((data.fit_type == "best") & (data.type_of_fit == "step_ept_het") & (data.min_e_mev<0.03295087252) & (data.max_e_mev >0.6859485403) , np.nan)
step_ept = data.where((data.fit_type == "best") & (data.type_of_fit == "step_ept") & (data.min_e_mev<0.03295087252) & (data.max_e_mev >0.07803193193) , np.nan)
ept_het = data.where((data.fit_type == "best") & (data.type_of_fit == "ept_het")  , np.nan)
step = data.where((data.fit_type == "best") & (data.type_of_fit == "step" ) , np.nan)
ept = data.where((data.fit_type == "best") & (data.type_of_fit == "ept") , np.nan)


one_step_ept_het = step_ept_het.where((step_ept_het.averaging == 1), np.nan)
two_step_ept_het = step_ept_het.where((step_ept_het.averaging == 2), np.nan)
five_step_ept_het= step_ept_het.where((step_ept_het.averaging == 5), np.nan)

one_step_ept = step_ept.where((step_ept.averaging == 1), np.nan)
two_step_ept = step_ept.where((step_ept.averaging == 2), np.nan)
five_step_ept= step_ept.where((step_ept.averaging == 5), np.nan)

one_ept_het = ept_het.where((ept_het.averaging == 1), np.nan)
two_ept_het = ept_het.where((ept_het.averaging == 2), np.nan)
five_ept_het= ept_het.where((ept_het.averaging == 5), np.nan)

one_step = step.where((step.averaging == 1), np.nan)
two_step = step.where((step.averaging == 2), np.nan)
five_step= step.where((step.averaging == 5), np.nan)

one_ept = ept.where((ept.averaging == 1), np.nan)
two_ept = ept.where((ept.averaging == 2), np.nan)
five_ept= ept.where((ept.averaging == 5), np.nan)

# %%
step_ept_het_c = data_c.where((data_c.fit_type == "best") & (data_c.type_of_fit == "step_ept_het") & (data_c.min_e_mev<0.03295087252) & (data_c.max_e_mev >0.6859485403) , np.nan)
step_ept_c = data_c.where((data_c.fit_type == "best") & (data_c.type_of_fit == "step_ept") & (data_c.min_e_mev<0.03295087252) & (data_c.max_e_mev >0.07803193193) , np.nan)
ept_het_c = data_c.where((data_c.fit_type == "best") & (data_c.type_of_fit == "ept_het")  , np.nan)
step_c = data_c.where((data_c.fit_type == "best") & (data_c.type_of_fit == "step" ) , np.nan)
ept_c = data_c.where((data_c.fit_type == "best") & (data_c.type_of_fit == "ept") , np.nan)


one_step_ept_het_c = step_ept_het_c.where((step_ept_het_c.averaging == 1), np.nan)
two_step_ept_het_c = step_ept_het_c.where((step_ept_het_c.averaging == 2), np.nan)
five_step_ept_het_c= step_ept_het_c.where((step_ept_het_c.averaging == 5), np.nan)

one_step_ept_c = step_ept_c.where((step_ept_c.averaging == 1), np.nan)
two_step_ept_c = step_ept_c.where((step_ept_c.averaging == 2), np.nan)
five_step_ept_c= step_ept_c.where((step_ept_c.averaging == 5), np.nan)

one_ept_het_c = ept_het_c.where((ept_het_c.averaging == 1), np.nan)
two_ept_het_c = ept_het_c.where((ept_het_c.averaging == 2), np.nan)
five_ept_het_c= ept_het_c.where((ept_het_c.averaging == 5), np.nan)

one_step_c = step_c.where((step_c.averaging == 1), np.nan)
two_step_c = step_c.where((step_c.averaging == 2), np.nan)
five_step_c= step_c.where((step_c.averaging == 5), np.nan)

one_ept_c = ept_c.where((ept_c.averaging == 1), np.nan)
two_ept_c = ept_c.where((ept_c.averaging == 2), np.nan)
five_ept_c= ept_c.where((ept_c.averaging == 5), np.nan)

# %%
one_step_ept_c['distance_au'].count()
# Out:
# 10

# %%
n1_step_ept_het = str(one_step_ept_het['distance_au'].count())
n2_step_ept_het = str(two_step_ept_het['distance_au'].count())
n5_step_ept_het = str(five_step_ept_het['distance_au'].count())

n1_step_ept = str(one_step_ept['distance_au'].count())
n2_step_ept = str(two_step_ept['distance_au'].count())
n5_step_ept = str(five_step_ept['distance_au'].count())

n1_ept_het = str(one_ept_het['distance_au'].count())
n2_ept_het = str(two_ept_het['distance_au'].count())
n5_ept_het = str(five_ept_het['distance_au'].count())

n1_step = str(one_step['distance_au'].count())
n2_step = str(two_step['distance_au'].count())
n5_step = str(five_step['distance_au'].count())

n1_ept = str(one_ept['distance_au'].count())
n2_ept = str(two_ept['distance_au'].count())
n5_ept = str(five_ept['distance_au'].count())

# %%
n1_step_ept_het_c = str(one_step_ept_het_c['distance_au'].count())
n2_step_ept_het_c = str(two_step_ept_het_c['distance_au'].count())
n5_step_ept_het_c = str(five_step_ept_het_c['distance_au'].count())

n1_step_ept_c = str(one_step_ept_c['distance_au'].count())
n2_step_ept_c = str(two_step_ept_c['distance_au'].count())
n5_step_ept_c = str(five_step_ept_c['distance_au'].count())

n1_ept_het_c = str(one_ept_het_c['distance_au'].count())
n2_ept_het_c = str(two_ept_het_c['distance_au'].count())
n5_ept_het_c = str(five_ept_het_c['distance_au'].count())

n1_step_c = str(one_step_c['distance_au'].count())
n2_step_c = str(two_step_c['distance_au'].count())
n5_step_c = str(five_step_c['distance_au'].count())

n1_ept_c = str(one_ept_c['distance_au'].count())
n2_ept_c = str(two_ept_c['distance_au'].count())
n5_ept_c = str(five_ept_c['distance_au'].count())

# %%
f, ax = plt.subplots(3,2, figsize=(10,10)) 

ax[0,0].hist(one_step_ept_het['break_point_mev'], bins=np.arange(0,0.15,0.01), align='right', color='red', edgecolor='black', label = 'step ept het D<0.7', alpha = 0.5)
ax[0,1].hist(one_step_ept['break_point_mev'], bins=np.arange(0,0.15,0.01), align='right', color='red', edgecolor='black', label = 'step ept D<0.7', alpha = 0.5)
ax[1,0].hist(one_ept_het['break_point_mev'], bins=np.arange(0,0.15,0.01), align='right', color='red', edgecolor='black', label = 'ept het D<0.7', alpha = 0.5)
ax[1,1].hist(one_step['break_point_mev'], bins=np.arange(0,0.15,0.01), align='right', color='red', edgecolor='black', label = 'step D<0.7', alpha = 0.5)
ax[2,0].hist(one_ept['break_point_mev'], bins=np.arange(0,0.15,0.01), align='right', color='red', edgecolor='black', label = 'ept D<0.7', alpha = 0.5)

ax[0,0].hist(one_step_ept_het_c['break_point_mev'], bins=np.arange(0,0.15,0.01), align='right', color='blue', edgecolor='black', label = 'step ept het D>0.7', alpha = 0.5)
ax[0,1].hist(one_step_ept_c['break_point_mev'], bins=np.arange(0,0.15,0.01), align='right', color='blue', edgecolor='black', label = 'step ept D>0.7', alpha = 0.5)
ax[1,0].hist(one_ept_het_c['break_point_mev'], bins=np.arange(0,0.15,0.01), align='right', color='blue', edgecolor='black', label = 'ept het D>0.7', alpha = 0.5)
ax[1,1].hist(one_step_c['break_point_mev'], bins=np.arange(0,0.15,0.01), align='right', color='blue', edgecolor='black', label = 'step D>0.7', alpha = 0.5)
ax[2,0].hist(one_ept_c['break_point_mev'], bins=np.arange(0,0.15,0.01), align='right', color='blue', edgecolor='black', label = 'ept D>0.7', alpha = 0.5)


ax[0,0].set_xlabel('Break point [MeV]', size=12)
ax[0,1].set_xlabel('Break point [MeV]', size=12)
ax[1,0].set_xlabel('Break point [MeV]', size=12)
ax[1,0].set_xlabel('Break point [MeV]', size=12)
ax[1,1].set_xlabel('Break point [MeV]', size=12)
ax[2,0].set_xlabel('Break point [MeV]', size=12)


ax[0,0].grid()
ax[0,0].legend(prop={'size': 10})
ax[0,0].set_ylim(0,4.2)

ax[0,1].grid()
ax[0,1].legend(prop={'size': 10})
ax[0,1].set_ylim(0,4.2)

ax[1,0].grid()
ax[1,0].legend(prop={'size': 10})
ax[1,0].set_ylim(0,4.2)


ax[1,1].grid()
ax[1,1].legend(prop={'size': 10})
ax[1,1].set_ylim(0,4.2)

ax[2,0].grid()
ax[2,0].legend(prop={'size': 10})
ax[2,0].set_ylim(0,4.2)


ax[0,0].set_title('One min av'+'\n'+'step ept het:  '+ n1_step_ept_het+' '+'step ept: '+n1_step_ept+'\n'+'ept het: '+n1_ept_het+' '+'step: '+n1_step+' '+'ept: '+n1_ept)
ax[0,1].set_title('One min av'+'\n'+'step ept het:  '+ n1_step_ept_het_c+' '+'step ept: '+n1_step_ept_c+'\n'+'ept het: '+n1_ept_het_c+' '+'step: '+n1_step_c+' '+'ept: '+n1_ept_c)

f.delaxes(ax[2,1]) #The indexing is zero-based here


plt.tick_params(axis='x', which='minor', labelsize=10)
#ax.xaxis.set_minor_formatter(FormatStrFormatter("%.2f"))
    #plt.tick_params(axis='y', which='minor')
    #ax.yaxis.set_minor_formatter(FormatStrFormatter("%.0f"))

plt.xticks(size=10)
plt.yticks(size=10)
# Out:
# (array([0., 1., 2., 3., 4., 5.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
f, ax = plt.subplots(3,2, figsize=(10,10)) 

ax[0,0].hist(two_step_ept_het['break_point_mev'], bins=np.arange(0,0.3,0.01), align='right', color='red', edgecolor='black', label = 'step ept het D<0.7', alpha = 0.5)
ax[0,1].hist(two_step_ept['break_point_mev'], bins=np.arange(0,0.3,0.01), align='right', color='red', edgecolor='black', label = 'step ept D<0.7', alpha = 0.5)
ax[1,0].hist(two_ept_het['break_point_mev'], bins=np.arange(0,0.3,0.01), align='right', color='red', edgecolor='black', label = 'ept het D<0.7', alpha = 0.5)
ax[1,1].hist(two_step['break_point_mev'], bins=np.arange(0,0.3,0.01), align='right', color='red', edgecolor='black', label = 'step D<0.7', alpha = 0.5)
ax[2,0].hist(two_ept['break_point_mev'], bins=np.arange(0,0.3,0.01), align='right', color='red', edgecolor='black', label = 'ept D<0.7', alpha = 0.5)

ax[0,0].hist(two_step_ept_het_c['break_point_mev'], bins=np.arange(0,0.3,0.01), align='right', color='blue', edgecolor='black', label = 'step ept het D>0.7', alpha = 0.5)
ax[0,1].hist(two_step_ept_c['break_point_mev'], bins=np.arange(0,0.3,0.01), align='right', color='blue', edgecolor='black', label = 'step ept D>0.7', alpha = 0.5)
ax[1,0].hist(two_ept_het_c['break_point_mev'], bins=np.arange(0,0.3,0.01), align='right', color='blue', edgecolor='black', label = 'ept het D>0.7', alpha = 0.5)
ax[1,1].hist(two_step_c['break_point_mev'], bins=np.arange(0,0.3,0.01), align='right', color='blue', edgecolor='black', label = 'step D>0.7', alpha = 0.5)
ax[2,0].hist(two_ept_c['break_point_mev'], bins=np.arange(0,0.3,0.01), align='right', color='blue', edgecolor='black', label = 'ept D>0.7', alpha = 0.5)


ax[0,0].set_xlabel('Break point [MeV]', size=12)
ax[0,1].set_xlabel('Break point [MeV]', size=12)
ax[1,0].set_xlabel('Break point [MeV]', size=12)
ax[1,0].set_xlabel('Break point [MeV]', size=12)
ax[1,1].set_xlabel('Break point [MeV]', size=12)
ax[2,0].set_xlabel('Break point [MeV]', size=12)


ax[0,0].grid()
ax[0,0].legend(prop={'size': 10})
ax[0,0].set_ylim(0,5.2)

ax[0,1].grid()
ax[0,1].legend(prop={'size': 10})
ax[0,1].set_ylim(0,5.2)

ax[1,0].grid()
ax[1,0].legend(prop={'size': 10})
ax[1,0].set_ylim(0,5.2)


ax[1,1].grid()
ax[1,1].legend(prop={'size': 10})
ax[1,1].set_ylim(0,5.2)

ax[2,0].grid()
ax[2,0].legend(prop={'size': 10})
ax[2,0].set_ylim(0,5.2)



ax[0,0].set_title('Two min av'+'\n'+'step ept het:  '+ n2_step_ept_het+' '+'step ept: '+n2_step_ept+'\n'+'ept het: '+n2_ept_het+' '+'step: '+n2_step+' '+'ept: '+n2_ept)
ax[0,1].set_title('Two min av'+'\n'+'step ept het:  '+ n2_step_ept_het_c+' '+'step ept: '+n2_step_ept_c+'\n'+'ept het: '+n2_ept_het_c+' '+'step: '+n2_step_c+' '+'ept: '+n2_ept_c)

f.delaxes(ax[2,1]) #The indexing is zero-based here


plt.tick_params(axis='x', which='minor', labelsize=10)
#ax.xaxis.set_minor_formatter(FormatStrFormatter("%.2f"))
    #plt.tick_params(axis='y', which='minor')
    #ax.yaxis.set_minor_formatter(FormatStrFormatter("%.0f"))

plt.xticks(size=10)
plt.yticks(size=10)
# Out:
# (array([0., 1., 2., 3., 4., 5., 6.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
f, ax = plt.subplots(3,2, figsize=(10,10)) 

ax[0,0].hist(five_step_ept_het['break_point_mev'], bins=np.arange(0,0.2,0.01), align='right', color='red', edgecolor='black', label = 'step ept het D<0.7', alpha = 0.5)
ax[0,1].hist(five_step_ept['break_point_mev'], bins=np.arange(0,0.2,0.01), align='right', color='red', edgecolor='black', label = 'step ept D<0.7', alpha = 0.5)
ax[1,0].hist(five_ept_het['break_point_mev'], bins=np.arange(0,0.2,0.01), align='right', color='red', edgecolor='black', label = 'ept het D<0.7', alpha = 0.5)
ax[1,1].hist(five_step['break_point_mev'], bins=np.arange(0,0.2,0.01), align='right', color='red', edgecolor='black', label = 'step D<0.7', alpha = 0.5)
ax[2,0].hist(five_ept['break_point_mev'], bins=np.arange(0,0.2,0.01), align='right', color='red', edgecolor='black', label = 'ept D<0.7', alpha = 0.5)

ax[0,0].hist(five_step_ept_het_c['break_point_mev'], bins=np.arange(0,0.2,0.01), align='right', color='blue', edgecolor='black', label = 'step ept het D>0.7', alpha = 0.5)
ax[0,1].hist(five_step_ept_c['break_point_mev'], bins=np.arange(0,0.2,0.01), align='right', color='blue', edgecolor='black', label = 'step ept D>0.7', alpha = 0.5)
ax[1,0].hist(five_ept_het_c['break_point_mev'], bins=np.arange(0,0.2,0.01), align='right', color='blue', edgecolor='black', label = 'ept het D>0.7', alpha = 0.5)
ax[1,1].hist(five_step_c['break_point_mev'], bins=np.arange(0,0.2,0.01), align='right', color='blue', edgecolor='black', label = 'step D>0.7', alpha = 0.5)
ax[2,0].hist(five_ept_c['break_point_mev'], bins=np.arange(0,0.2,0.01), align='right', color='blue', edgecolor='black', label = 'ept D>0.7', alpha = 0.5)


ax[0,0].set_xlabel('Break point [MeV]', size=12)
ax[0,1].set_xlabel('Break point [MeV]', size=12)
ax[1,0].set_xlabel('Break point [MeV]', size=12)
ax[1,0].set_xlabel('Break point [MeV]', size=12)
ax[1,1].set_xlabel('Break point [MeV]', size=12)
ax[2,0].set_xlabel('Break point [MeV]', size=12)


ax[0,0].grid()
ax[0,0].legend(prop={'size': 10})
ax[0,0].set_ylim(0,5.2)

ax[0,1].grid()
ax[0,1].legend(prop={'size': 10})
ax[0,1].set_ylim(0,5.2)

ax[1,0].grid()
ax[1,0].legend(prop={'size': 10})
ax[1,0].set_ylim(0,5.2)


ax[1,1].grid()
ax[1,1].legend(prop={'size': 10})
ax[1,1].set_ylim(0,5.2)

ax[2,0].grid()
ax[2,0].legend(prop={'size': 10})
ax[2,0].set_ylim(0,5.2)

ax[0,0].set_title('Five min av'+'\n'+'step ept het:  '+ n5_step_ept_het+' '+'step ept: '+n5_step_ept+'\n'+'ept het: '+n5_ept_het+' '+'step: '+n5_step+' '+'ept: '+n5_ept)
ax[0,1].set_title('Five min av'+'\n'+'step ept het:  '+ n5_step_ept_het_c+' '+'step ept: '+n5_step_ept_c+'\n'+'ept het: '+n5_ept_het_c+' '+'step: '+n5_step_c+' '+'ept: '+n5_ept_c)

f.delaxes(ax[2,1]) #The indexing is zero-based here

plt.tick_params(axis='x', which='minor', labelsize=10)
#ax.xaxis.set_minor_formatter(FormatStrFormatter("%.2f"))
    #plt.tick_params(axis='y', which='minor')
    #ax.yaxis.set_minor_formatter(FormatStrFormatter("%.0f"))

plt.xticks(size=10)
plt.yticks(size=10)
# Out:
# (array([0., 1., 2., 3., 4., 5., 6.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
f, ax = plt.subplots(1,3, figsize=(30,10)) 

ax[0].errorbar(x=one_step_ept['break_point_mev'], y=one_step_ept['distance_au'], xerr=one_step_ept['break_point_err_mev'], color='red', fmt='o', markersize=5, ecolor='red', zorder=0, alpha=0.9)#, label='Flux average')
ax[0].errorbar(x=one_step_ept_c['break_point_mev'], y=one_step_ept_c['distance_au'], xerr=one_step_ept_c['break_point_err_mev'], color='blue', fmt='o', markersize=5, ecolor='blue', zorder=0, alpha=0.9)#, label='Flux average')

#ax[0].errorbar(df_zero_err_one.break_point_mev, df_zero_err_one.gamma1, xerr=df_zero_err_one['break_point_err_mev'], fmt='o', markersize=5, c='black', label='zero err', alpha=1)
ax[0].set_xlabel('Break energy [MeV]', size=15)
ax[0].set_ylabel('Distance [AU]', size=15)
ax[0].set_title('One min av'+'\n'+'Events:  '+ n1_step_ept_het)
ax[0].grid()

ax[1].errorbar(x=two_step_ept['break_point_mev'], y=two_step_ept['distance_au'],  xerr=two_step_ept['break_point_err_mev'], color='red', fmt='o', markersize=5, ecolor='red', zorder=0, alpha=0.9)#, label='Flux average')
ax[1].errorbar(x=two_step_ept_c['break_point_mev'], y=two_step_ept_c['distance_au'],  xerr=two_step_ept_c['break_point_err_mev'], color='blue', fmt='o', markersize=5, ecolor='blue', zorder=0, alpha=0.9)#, label='Flux average')

#ax[1].errorbar(df_zero_err_two.break_point_mev, df_zero_err_two.gamma1, xerr=df_zero_err_two['break_point_err_mev'], fmt='o', markersize=5, c='black', label='zero err', alpha=1)
ax[1].set_xlabel('Break energy [MeV]', size=15)
ax[1].set_ylabel('Distance [AU]', size=15)
ax[1].set_title('Two min av'+'\n'+'Events:  '+ n2_step_ept_het)
ax[1].grid()

ax[2].errorbar(x=five_step_ept['break_point_mev'], y=five_step_ept['distance_au'],  xerr=five_step_ept['break_point_err_mev'], color='red', fmt='o', markersize=5, ecolor='red', zorder=0, alpha=0.9)#, label='Flux average')
ax[2].errorbar(x=five_step_ept_c['break_point_mev'], y=five_step_ept_c['distance_au'],  xerr=five_step_ept_c['break_point_err_mev'], color='blue', fmt='o', markersize=5, ecolor='blue', zorder=0, alpha=0.9)#, label='Flux average')

#ax[2].errorbar(df_zero_err_five.break_point_mev, df_zero_err_five.gamma1, xerr=df_zero_err_five['break_point_err_mev'], fmt='o', markersize=5, c='black', label='zero err', alpha=1)
ax[2].set_xlabel('Break energy [MeV]', size=15)
ax[2].set_ylabel('Distance [AU]', size=15)
ax[2].set_title('Five min av'+'\n'+'Events:  '+ n5_step_ept_het)
ax[2].grid()

plt.tick_params(axis='x', which='minor', labelsize=15)
#ax.xaxis.set_minor_formatter(FormatStrFormatter("%.2f"))
    #plt.tick_params(axis='y', which='minor')
    #ax.yaxis.set_minor_formatter(FormatStrFormatter("%.0f"))
plt.legend(prop={'size': 15})
plt.xticks(size=15)
plt.yticks(size=15)


#ax.set_ylim(-20,0)
#plt.title('Events:  '+ number+'  Zero err: '+ zero)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
