# %%
from matplotlib.ticker import LinearLocator, MultipleLocator, AutoMinorLocator
import matplotlib.dates as mdates
from matplotlib.ticker import FormatStrFormatter
from adjustText import adjust_text
from astropy import units as u
import sys
import site
import matplotlib.pyplot as plt
from math import *
from tkinter import *
import astropy.units as u
import numpy as np
import pandas as pd
import plotly.express as px

# %%
fit_run = pd.read_excel(r'C:\Users\Omistaja\Desktop\SRL\2021SRL\epd_plot-main\solo_loader-main-shift\events\fit-run-all.xlsx')
make_fit = pd.read_excel(r'C:\Users\Omistaja\Desktop\SRL\2021SRL\epd_plot-main\solo_loader-main-shift\events\make-fit.xlsx')

# %%
data = pd.concat([fit_run, make_fit], axis=1)

# %%
data.columns
# Out:
# Index(['Source.Name', 'Column1', 'date', 'averaging_min', 'direction',
#        'data_type', 'min_e_mev', 'max_e_mev', 'distance_au', 'STEP', 'EPT',
#        'HET', 'sigma', 'relative_error', 'fraction_of_nan',
#        'leave_first_het_channel_out', 'shift_step_data', 'type_of_fit',
#        'fit_to', 'window', 'which_fit', 'min_energy', 'max_energy',
#        'gamma1_guess', 'gamma2_guess', 'c1_guess', 'alpha_guess',
#        'break_guess_mev', 'cutoff_point_guess_mev', 'use_random', 'iterations',
#        'Source.Name', 'averaging', 'final_fit_type', 'reduced_chi_sq', 'c1',
#        'c1_err', 'gamma1', 'gamma1_err', 'gamma2', 'gamma2_err',
#        'break_point_mev', 'break_point_err_mev', 'exp_cutoff_point_mev',
#        'cutoff_err_mev', 'alpha', 'year', 'month', 'day', 'time', 'fit_to',
#        'fit_type', 'data', 'aver', 'step', 'ept', 'het'],
#       dtype='object')

# %% [markdown]
# ### Energy channels:
# #### step energy range: 0.004323343613-0.07803193193
# #### ept energy range: 0.03295087252-0.452730295
# #### het energy range: 0.6859485403-10.62300288
# #### second het channel: 1.590048112

# %%
data = pd.concat([fit_run, make_fit], axis=1)
data.query('fit_type == "best" and type_of_fit == "step_ept_het" and min_e_mev<0.03295087252 and max_e_mev >0.6859485403' , inplace = True)

one = data.where((data.averaging == 1), np.nan)
two = data.where((data.averaging == 2), np.nan)
five= data.where((data.averaging == 5), np.nan)

n1 = str(one['gamma1'].count())
n2 = str(two['gamma1'].count())
n5 = str(five['gamma1'].count())

df_zero_err_one = one.where((data['break_point_err_mev'] == 0), np.nan)
df_zero_err_two = two.where((data['break_point_err_mev'] == 0), np.nan)
df_zero_err_five = five.where((data['break_point_err_mev'] == 0), np.nan)


zero1 =  str(df_zero_err_one['gamma1'].count())
zero2 =  str(df_zero_err_two['gamma1'].count())
zero5 =  str(df_zero_err_five['gamma1'].count())

# %%
f, ax = plt.subplots(3,1, figsize=(10,30)) 

ax[0].hist(one['gamma1'], bins=np.arange(-5,0,0.1), align='right', color='purple', edgecolor='black')
ax[0].set_xlabel('$\gamma_1$', size=12)
ax[0].set_title('One min av'+'\n'+'Events:  '+ n1+'  Zero err: '+ zero1)
ax[0].grid()

ax[1].hist(two['gamma1'], bins=np.arange(-5,0,0.1), align='right', color='purple', edgecolor='black')
ax[1].set_xlabel('$\gamma_1$', size=12)
ax[1].set_title('One min av'+'\n'+'Events:  '+ n2+'  Zero err: '+ zero2)
ax[1].grid()

ax[2].hist(five['gamma1'], bins=np.arange(-5,0,0.1), align='right', color='purple', edgecolor='black')
ax[2].set_xlabel('$\gamma_1$', size=12)
ax[2].set_title('One min av'+'\n'+'Events:  '+ n5+'  Zero err: '+ zero5)
ax[2].grid()

plt.tick_params(axis='x', which='minor', labelsize=10)
#ax.xaxis.set_minor_formatter(FormatStrFormatter("%.2f"))
    #plt.tick_params(axis='y', which='minor')
    #ax.yaxis.set_minor_formatter(FormatStrFormatter("%.0f"))
plt.legend(prop={'size': 10})
plt.xticks(size=10)
plt.yticks(size=10)


#ax.set_ylim(-20,0)
#plt.title('Events:  '+ number+'  Zero err: '+ zero)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
f, ax = plt.subplots(3,1, figsize=(10,30)) 

ax[0].hist(one['gamma2'], bins=np.arange(-5,0,0.1), align='right', color='purple', edgecolor='black')
ax[0].set_xlabel('$\gamma_2$', size=12)
ax[0].set_title('One min av'+'\n'+'Events:  '+ n1+'  Zero err: '+ zero1)
ax[0].grid()

ax[1].hist(two['gamma2'], bins=np.arange(-5,0,0.1), align='right', color='purple', edgecolor='black')
ax[1].set_xlabel('$\gamma_2$', size=12)
ax[1].set_title('One min av'+'\n'+'Events:  '+ n2+'  Zero err: '+ zero2)
ax[1].grid()

ax[2].hist(five['gamma2'], bins=np.arange(-5,0,0.1), align='right', color='purple', edgecolor='black')
ax[2].set_xlabel('$\gamma_2$', size=12)
ax[2].set_title('One min av'+'\n'+'Events:  '+ n5+'  Zero err: '+ zero5)
ax[2].grid()

plt.tick_params(axis='x', which='minor', labelsize=10)
#ax.xaxis.set_minor_formatter(FormatStrFormatter("%.2f"))
    #plt.tick_params(axis='y', which='minor')
    #ax.yaxis.set_minor_formatter(FormatStrFormatter("%.0f"))
plt.legend(prop={'size': 10})
plt.xticks(size=10)
plt.yticks(size=10)


#ax.set_ylim(-20,0)
#plt.title('Events:  '+ number+'  Zero err: '+ zero)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
f, ax = plt.subplots(3,1, figsize=(10,30)) 

ax[0].hist(one['break_point_mev'], bins=np.arange(0,0.3,0.01), align='right', color='purple', edgecolor='black')
ax[0].set_xlabel('Break point [MeV]', size=12)
ax[0].set_title('One min av'+'\n'+'Events:  '+ n1+'  Zero err: '+ zero1)
ax[0].grid()

ax[1].hist(two['break_point_mev'], bins=np.arange(0,0.3,0.01), align='right', color='purple', edgecolor='black')
ax[1].set_xlabel('Break point [MeV]', size=12)
ax[1].set_title('One min av'+'\n'+'Events:  '+ n2+'  Zero err: '+ zero2)
ax[1].grid()

ax[2].hist(five['break_point_mev'], bins=np.arange(0,0.3,0.01), align='right', color='purple', edgecolor='black')
ax[2].set_xlabel('Break point [MeV]', size=12)
ax[2].set_title('One min av'+'\n'+'Events:  '+ n5+'  Zero err: '+ zero5)
ax[2].grid()

plt.tick_params(axis='x', which='minor', labelsize=10)
#ax.xaxis.set_minor_formatter(FormatStrFormatter("%.2f"))
    #plt.tick_params(axis='y', which='minor')
    #ax.yaxis.set_minor_formatter(FormatStrFormatter("%.0f"))
plt.legend(prop={'size': 10})
plt.xticks(size=10)
plt.yticks(size=10)


#ax.set_ylim(-20,0)
#plt.title('Events:  '+ number+'  Zero err: '+ zero)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
f, ax = plt.subplots(3,1, figsize=(10,30)) 

ax[0].hist(one['c1'], bins=np.arange(0,1.6e5,2000), align='right', color='purple', edgecolor='black')
ax[0].set_xlabel('c1 [MeV]', size=12)
ax[0].set_title('One min av'+'\n'+'Events:  '+ n1+'  Zero err: '+ zero1)
ax[0].grid()
ax[0].set_xscale('log')

ax[1].hist(two['c1'], bins=np.arange(0,1.6e5,2000), align='right', color='purple', edgecolor='black')
ax[1].set_xlabel('c1 [MeV]', size=12)
ax[1].set_title('c1'+'\n'+'Events:  '+ n2+'  Zero err: '+ zero2)
ax[1].grid()

ax[2].hist(five['c1'], bins=np.arange(0,1.6e5,2000), align='right', color='purple', edgecolor='black')
ax[2].set_xlabel('c1 [MeV]', size=12)
ax[2].set_title('One min av'+'\n'+'Events:  '+ n5+'  Zero err: '+ zero5)
ax[2].grid()

plt.tick_params(axis='x', which='minor', labelsize=10)
#ax.xaxis.set_minor_formatter(FormatStrFormatter("%.2f"))
    #plt.tick_params(axis='y', which='minor')
    #ax.yaxis.set_minor_formatter(FormatStrFormatter("%.0f"))
plt.legend(prop={'size': 10})
plt.xticks(size=10)
plt.yticks(size=10)


#ax.set_ylim(-20,0)
#plt.title('Events:  '+ number+'  Zero err: '+ zero)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
f, ax = plt.subplots(3,1, figsize=(10,30)) 

ax[0].hist(one['alpha'],  bins=np.arange(0,300,10), align='right', color='purple', edgecolor='black')
ax[0].set_xlabel(r'$\alpha$', size=12)
ax[0].set_title('One min av'+'\n'+'Events:  '+ n1+'  Zero err: '+ zero1)
ax[0].grid()

ax[1].hist(two['alpha'],  bins=np.arange(0,300,10), align='right', color='purple', edgecolor='black')
ax[1].set_xlabel(r'$\alpha$', size=12)
ax[1].set_title('c1'+'\n'+'Events:  '+ n2+'  Zero err: '+ zero2)
ax[1].grid()

ax[2].hist(five['alpha'], bins=np.arange(0,300,10), align='right', color='purple', edgecolor='black')
ax[2].set_xlabel(r'$\alpha$', size=12)
ax[2].set_title('One min av'+'\n'+'Events:  '+ n5+'  Zero err: '+ zero5)
ax[2].grid()

plt.tick_params(axis='x', which='minor', labelsize=10)
#ax.xaxis.set_minor_formatter(FormatStrFormatter("%.2f"))
    #plt.tick_params(axis='y', which='minor')
    #ax.yaxis.set_minor_formatter(FormatStrFormatter("%.0f"))
plt.legend(prop={'size': 10})
plt.xticks(size=10)
plt.yticks(size=10)


#ax.set_ylim(-20,0)
#plt.title('Events:  '+ number+'  Zero err: '+ zero)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
